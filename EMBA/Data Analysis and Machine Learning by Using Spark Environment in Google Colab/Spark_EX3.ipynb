# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 44 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 53.9 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845514 sha256=a8121b4d7d4c657243c7dccf79ad1de0faaf77da7daf998c9f320c216970ebf4
#   Stored in directory: /root/.cache/pip/wheels/42/59/f5/79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %%
import numpy as np
from pyspark.sql import SparkSession
# %matplotlib inline

# %%
spark = SparkSession.builder \
   .master("local") \
   .appName("StockMarket") \
   .config("spark.executor.memory", "6gb") \
   .getOrCreate()

# %%
df =spark.read.format('com.databricks.spark.csv')\
     .options(header='true', inferschema='true')\
     .load('AAPL.csv')

# %%
df.show()
# Out:
# +-------------------+--------+--------+--------+--------+---------+---------+
# |               Date|    Open|    High|     Low|   Close|Adj Close|   Volume|
# +-------------------+--------+--------+--------+--------+---------+---------+
# |2000-01-03 00:00:00|3.745536|4.017857|3.631696|3.997768|  2.69592|133949200|
# |2000-01-04 00:00:00|3.866071|3.950893|3.613839|3.660714| 2.468626|128094400|
# |2000-01-05 00:00:00|3.705357|3.948661|3.678571|3.714286| 2.504751|194580400|
# |2000-01-06 00:00:00|3.790179|3.821429|3.392857|3.392857| 2.287994|191993200|
# |2000-01-07 00:00:00|3.446429|3.607143|3.410714|3.553571| 2.396373|115183600|
# |2000-01-10 00:00:00|3.642857|3.651786|3.383929|3.491071| 2.354226|126266000|
# |2000-01-11 00:00:00|3.426339|3.549107|3.232143|  3.3125| 2.233805|110387200|
# |2000-01-12 00:00:00|3.392857|3.410714|3.089286|3.113839| 2.099837|244017200|
# |2000-01-13 00:00:00|3.374439|3.526786|3.303571|3.455357| 2.330141|258171200|
# |2000-01-14 00:00:00|3.571429|3.651786|3.549107|3.587054| 2.418951| 97594000|
# |2000-01-18 00:00:00|3.607143|3.785714|3.587054|3.712054| 2.503246|114794400|
# |2000-01-19 00:00:00|3.772321|3.883929|3.691964|3.805804| 2.566468|149410800|
# |2000-01-20 00:00:00|   4.125|4.339286|4.053571|4.053571| 2.733551|457783200|
# |2000-01-21 00:00:00|4.080357|4.080357|3.935268|3.975446| 2.680867|123981200|
# |2000-01-24 00:00:00|3.872768|4.026786|3.754464|3.794643| 2.558941|110219200|
# |2000-01-25 00:00:00|    3.75|4.040179| 3.65625|4.008929| 2.703446|124286400|
# |2000-01-26 00:00:00|3.928571|4.078125|3.919643|3.935268| 2.653772| 91789600|
# |2000-01-27 00:00:00|3.886161|4.035714|3.821429|3.928571| 2.649256| 85036000|
# |2000-01-28 00:00:00|3.863839|3.959821| 3.59375|3.629464| 2.447552|105837200|
# |2000-01-31 00:00:00|3.607143|3.709821|   3.375|3.705357| 2.498731|175420000|
# +-------------------+--------+--------+--------+--------+---------+---------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as f
df = df.withColumn('date', f.to_date('Date'))

# %%
df.show(n=5)
# Out:
# +----------+--------+--------+--------+--------+---------+---------+
# |      date|    Open|    High|     Low|   Close|Adj Close|   Volume|
# +----------+--------+--------+--------+--------+---------+---------+
# |2000-01-03|3.745536|4.017857|3.631696|3.997768|  2.69592|133949200|
# |2000-01-04|3.866071|3.950893|3.613839|3.660714| 2.468626|128094400|
# |2000-01-05|3.705357|3.948661|3.678571|3.714286| 2.504751|194580400|
# |2000-01-06|3.790179|3.821429|3.392857|3.392857| 2.287994|191993200|
# |2000-01-07|3.446429|3.607143|3.410714|3.553571| 2.396373|115183600|
# +----------+--------+--------+--------+--------+---------+---------+
# only showing top 5 rows

# %%
date_breakdown = ['year', 'month', 'day']
for i in enumerate(date_breakdown):
    index = i[0]
    name = i[1]
    df = df.withColumn(name, f.split('date', '-')[index])

# %%
df.show(n=10)
# Out:
# +----------+--------+--------+--------+--------+---------+---------+----+-----+---+
# |      date|    Open|    High|     Low|   Close|Adj Close|   Volume|year|month|day|
# +----------+--------+--------+--------+--------+---------+---------+----+-----+---+
# |2000-01-03|3.745536|4.017857|3.631696|3.997768|  2.69592|133949200|2000|   01| 03|
# |2000-01-04|3.866071|3.950893|3.613839|3.660714| 2.468626|128094400|2000|   01| 04|
# |2000-01-05|3.705357|3.948661|3.678571|3.714286| 2.504751|194580400|2000|   01| 05|
# |2000-01-06|3.790179|3.821429|3.392857|3.392857| 2.287994|191993200|2000|   01| 06|
# |2000-01-07|3.446429|3.607143|3.410714|3.553571| 2.396373|115183600|2000|   01| 07|
# |2000-01-10|3.642857|3.651786|3.383929|3.491071| 2.354226|126266000|2000|   01| 10|
# |2000-01-11|3.426339|3.549107|3.232143|  3.3125| 2.233805|110387200|2000|   01| 11|
# |2000-01-12|3.392857|3.410714|3.089286|3.113839| 2.099837|244017200|2000|   01| 12|
# |2000-01-13|3.374439|3.526786|3.303571|3.455357| 2.330141|258171200|2000|   01| 13|
# |2000-01-14|3.571429|3.651786|3.549107|3.587054| 2.418951| 97594000|2000|   01| 14|
# +----------+--------+--------+--------+--------+---------+---------+----+-----+---+
# only showing top 10 rows

# %%
df_plot = df.select('year', 'Adj Close').toPandas()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

df_plot.set_index('year', inplace=True)
df_plot.plot(figsize=(16, 6), grid=True)
plt.title('Apple stock')
plt.ylabel('Stock Quote ($)')
plt.show()

# %%
df.toPandas().shape
# Out:
# (4610, 10)

# %%
df.dropna().count()
# Out:
# 4610

# %%
df.select('Open', 'High', 'Low', 'Close', 'Adj Close').describe().show()
# Out:
# +-------+------------------+-----------------+-----------------+------------------+-----------------+
# |summary|              Open|             High|              Low|             Close|        Adj Close|
# +-------+------------------+-----------------+-----------------+------------------+-----------------+
# |  count|              4610|             4610|             4610|              4610|             4610|
# |   mean|46.319638522993586|46.75264737505422|  45.853888678091| 46.31249455574832|39.94770416811271|
# | stddev| 49.20256362250941| 49.5813980430415|48.81455218501357|49.203718795182205|47.79307553718152|
# |    min|          0.927857|         0.942143|         0.908571|          0.937143|         0.631968|
# |    max|        182.589996|            183.5|       180.210007|        181.720001|       181.021957|
# +-------+------------------+-----------------+-----------------+------------------+-----------------+

# %%
df.groupBy(['year']).agg({'Adj Close':'count'})\
            .withColumnRenamed('count(Adj Close)', 'Row Count')\
            .orderBy(["year"],ascending=False)\
            .show()
# Out:
# +----+---------+
# |year|Row Count|
# +----+---------+
# |2018|       82|
# |2017|      251|
# |2016|      252|
# |2015|      252|
# |2014|      252|
# |2013|      252|
# |2012|      250|
# |2011|      252|
# |2010|      252|
# |2009|      252|
# |2008|      253|
# |2007|      251|
# |2006|      251|
# |2005|      252|
# |2004|      252|
# |2003|      252|
# |2002|      252|
# |2001|      248|
# |2000|      252|
# +----+---------+

# %%
trainDF = df[df.year < 2017] 
testDF = df[df.year > 2016]

# %%
trainDF.toPandas().shape
# Out:
# (4277, 10)

# %%
testDF.toPandas().shape
# Out:
# (333, 10)

# %%
trainDF_plot = trainDF.select('year', 'Adj Close').toPandas()
trainDF_plot.set_index('year', inplace=True)
trainDF_plot.plot(figsize=(16, 6), grid=True)
plt.title('Apple Stock 2000-2016')
plt.ylabel('Stock Quote ($)')
plt.show()

# %%
testDF_plot = testDF.select('year', 'Adj Close').toPandas()
testDF_plot.set_index('year', inplace=True)
testDF_plot.plot(figsize=(16, 6), grid=True)
plt.title('Apple Stock 2017-2018')
plt.ylabel('Stock Quote ($)')
plt.show()

# %%
trainArray = np.array(trainDF.select('Open', 'High', 'Low', 'Close','Volume', 'Adj Close' ) \
         .collect())
testArray = np.array(testDF.select('Open', 'High', 'Low', 'Close','Volume', 'Adj Close' ) \
         .collect())

# %%
print(trainArray[0])
print('-------------')
print(testArray[0])
# Out:
# [3.745536e+00 4.017857e+00 3.631696e+00 3.997768e+00 1.339492e+08
#  2.695920e+00]
# -------------
# [1.15800003e+02 1.16330002e+02 1.14760002e+02 1.16150002e+02
#  2.87819000e+07 1.13410263e+02]

# %%
from sklearn.preprocessing import MinMaxScaler

minMaxScale = MinMaxScaler()
minMaxScale.fit(trainArray)

# %%
#minMaxScale.fit(trainArray)
# Out:
# MinMaxScaler()

# %%
testingArray = minMaxScale.transform(testArray)
trainingArray = minMaxScale.transform(trainArray)

# %%
print(testingArray[0])
print('--------------')
print(trainingArray[0])
# Out:
# [0.86025834 0.86369548 0.8724821  0.87240926 0.01026612 0.90325687]
# --------------
# [0.02110113 0.02302218 0.02086823 0.02317552 0.0672496  0.01653048]

# %%
xtrain = trainingArray[:, 0:-1]
xtest = testingArray[:, 0:-1]

ytrain = trainingArray[:, -1:]
ytest = testingArray[:, -1:]

# %%
trainingArray[0]
# Out:
# array([0.02110113, 0.02302218, 0.02086823, 0.02317552, 0.0672496 ,
#        0.01653048])

# %%
xtrain[0]
# Out:
# array([0.02110113, 0.02302218, 0.02086823, 0.02317552, 0.0672496 ])

# %%
ytrain[0]
# Out:
# array([0.01653048])

# %%
print('xtrain shape = {}'.format(xtrain.shape))
print('xtest shape = {}'.format(xtest.shape))
print('ytrain shape = {}'.format(ytrain.shape))
print('ytest shape = {}'.format(ytest.shape))
# Out:
# xtrain shape = (4277, 5)
# xtest shape = (333, 5)
# ytrain shape = (4277, 1)
# ytest shape = (333, 1)

# %%
plt.figure(figsize=(16,6))
plt.plot(xtrain[:,0],color='red', label='open')
plt.plot(xtrain[:,1],color='blue', label='high')
plt.plot(xtrain[:,2],color='green', label='low')
plt.plot(xtrain[:,3],color='purple', label='close')
plt.legend(loc = 'upper left')
plt.title('Open, High, Low, and Close by Day')
plt.xlabel('Days')
plt.ylabel('Scaled Quotes')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(xtrain[:,4],color='black', label='volume')
plt.legend(loc = 'upper right')
plt.title('Volume by Day')
plt.xlabel('Days')
plt.ylabel('Scaled Volume')
plt.show()

# %%
from keras import models, layers

# %%
from keras import models, layers

model = models.Sequential()
model.add(layers.LSTM(1, input_shape=(1,5)))
model.add(layers.Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
xtrain = xtrain.reshape((xtrain.shape[0], 1, xtrain.shape[1]))
xtest  = xtest.reshape((xtest.shape[0], 1, xtest.shape[1]))

# %%
print('The shape of xtrain is {}: '.format(xtrain.shape))
print('The shape of xtest is {}: '.format(xtest.shape))
# Out:
# The shape of xtrain is (4277, 1, 5):
# The shape of xtest is (333, 1, 5):

# %%
loss = model.fit(xtrain, ytrain, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 428/428 [==============================] - 3s 2ms/step - loss: 0.1135
# Epoch 2/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0849
# Epoch 3/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0535
# Epoch 4/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 5/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0042
# Epoch 6/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0030
# Epoch 7/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0025
# Epoch 8/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0022
# Epoch 9/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 10/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0017
# Epoch 11/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0016
# Epoch 12/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 13/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 14/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 15/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 16/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0011
# Epoch 17/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0011
# Epoch 18/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/step - loss: 9.7760e-04
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/step - loss: 9.5677e-04
# Epoch 22/100
# 428/428 [==============================] - 1s 2ms/step - loss: 9.3652e-04
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/step - loss: 9.1247e-04
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.9679e-04
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.8856e-04
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.8462e-04
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.6802e-04
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.6419e-04
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.5556e-04
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.5148e-04
# Epoch 31/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.4315e-04
# Epoch 32/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.3121e-04
# Epoch 33/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.2455e-04
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.2748e-04
# Epoch 35/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.1971e-04
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.2400e-04
# Epoch 37/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.2448e-04
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.1328e-04
# Epoch 39/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.1415e-04
# Epoch 40/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.0754e-04
# Epoch 41/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.1282e-04
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.0715e-04
# Epoch 43/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.0145e-04
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9705e-04
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.0333e-04
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.0419e-04
# Epoch 47/100
# 428/428 [==============================] - 1s 2ms/step - loss: 8.0722e-04
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9167e-04
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9830e-04
# Epoch 50/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9436e-04
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9434e-04
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9496e-04
# Epoch 53/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9088e-04
# Epoch 54/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9335e-04
# Epoch 55/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8704e-04
# Epoch 56/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8751e-04
# Epoch 57/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8312e-04
# Epoch 58/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9255e-04
# Epoch 59/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9366e-04
# Epoch 60/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9082e-04
# Epoch 61/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8831e-04
# Epoch 62/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8105e-04
# Epoch 63/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8511e-04
# Epoch 64/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8710e-04
# Epoch 65/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8544e-04
# Epoch 66/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8596e-04
# Epoch 67/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.9142e-04
# Epoch 68/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8644e-04
# Epoch 69/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8765e-04
# Epoch 70/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8877e-04
# Epoch 71/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7860e-04
# Epoch 72/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.8345e-04
# Epoch 73/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8206e-04
# Epoch 74/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8292e-04
# Epoch 75/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8154e-04
# Epoch 76/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8636e-04
# Epoch 77/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8143e-04
# Epoch 78/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.7998e-04
# Epoch 79/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.8353e-04
# Epoch 80/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.9054e-04
# Epoch 81/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7994e-04
# Epoch 82/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8167e-04
# Epoch 83/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7873e-04
# Epoch 84/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.8136e-04
# Epoch 85/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.7623e-04
# Epoch 86/100
# 428/428 [==============================] - 1s 3ms/step - loss: 7.8430e-04
# Epoch 87/100
# 428/428 [==============================] - 2s 4ms/step - loss: 7.7386e-04
# Epoch 88/100
# 428/428 [==============================] - 3s 7ms/step - loss: 7.7617e-04
# Epoch 89/100
# 428/428 [==============================] - 3s 7ms/step - loss: 7.7375e-04
# Epoch 90/100
# 428/428 [==============================] - 3s 7ms/step - loss: 7.7380e-04
# Epoch 91/100
# 428/428 [==============================] - 2s 5ms/step - loss: 7.6985e-04
# Epoch 92/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7810e-04
# Epoch 93/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7296e-04
# Epoch 94/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.6355e-04
# Epoch 95/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7725e-04
# Epoch 96/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.8201e-04
# Epoch 97/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.6816e-04
# Epoch 98/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.6801e-04
# Epoch 99/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7891e-04
# Epoch 100/100
# 428/428 [==============================] - 1s 2ms/step - loss: 7.7242e-04

# %%
plt.plot(loss.history['loss'], label = 'loss')
plt.title('mean squared error by epoch')
plt.legend()
plt.show()

# %%
predicted = model.predict(xtest)
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %%
combined_array = np.concatenate((ytest, predicted), axis = 1)

# %%
plt.figure(figsize=(16,6))
plt.plot(combined_array[:,0],color='red', label='actual')
plt.plot(combined_array[:,1],color='blue', label='predicted')
plt.legend(loc = 'lower right')
plt.title('2017 Actual vs. Predicted APPL Stock')
plt.xlabel('Days')
plt.ylabel('Scaled Quotes')
plt.show()

# %%
import sklearn.metrics as metrics

np.sqrt(metrics.mean_squared_error(ytest,predicted))
# Out:
# 0.02220244660868793
